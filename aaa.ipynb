# %% [markdown]
# input
#
# ![image.png](attachment:image.png)

# %% [markdown]
# green supply chain , robust optimization, characteristics
#
# dismantiling, classification, clustering

# %% [markdown]
# Output/classifications class
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Tensor flow :[[Python] 「純」Windows 下的 Deep Learning](http://yenlung-blog.logdown.com/posts/1598592)
#
# [【Deep Learning】Windows 10 64位安装TensorFlow](https://zhuanlan.zhihu.com/p/31344346)

# %% [markdown]
# The previous coursera course has presented the non-Bayesian based theory of learning techniques.
# The model can be classified as two classes: supervise learning and unsupervised learning.  However, all the previous knowledge focus on the discriminative model including writing recognition, face recognition, spam classifier.  Generative model is another dimension for the learning theory.
#
# Semi-supervised learning may apply to the data set that has few labels and large data set has no label.
# 当前非常流行的深度学习GAN模型和半监督学习的思路有相通之处，GAN是“生成对抗网络”（Generative Adversarial Networks）的简称，包括了一个生成模型G和一个判别模型D，GAN的目标函数是关于D与G的一个零和游戏，也是一个最小-最大化问题。
#
# GAN实际上就是生成模型和判别模型之间的一个模仿游戏。生成模型的目的，就是要尽量去模仿、建模和学习真实数据的分布规律；而判别模型则是要判别自己所得到的一个输入数据，究竟是来自于真实的数据分布还是来自于一个生成模型。通过这两个内部模型之间不断的竞争，从而提高两个模型的生成能力和判别能力。[link](https://zhuanlan.zhihu.com/p/26174370)
